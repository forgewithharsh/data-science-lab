# %% [markdown]
# # This is my First Colab Notebook
# Welcome to my colab notebook. I am very excited to work with colab.
#
# ```
# import os
# os.listdir()
# ```

# %%
print("Hello World")
# Out:
# Hello World

# %%
a = 87

# %%
print(a + 6)
# Out:
# 93

# %%
# !pip install pandas

# %%
pip install matplotlib

# %%
pip install tensorflow

# %%
pip install pyjokes
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.6/47.6 kB 2.3 MB/s eta 0:00:00
# ...

# %%
# !pwd
# Out:
# /content

# %%
ls
# Out:
# sample_data/

# %%
import matplotlib.pyplot as plt

# Sample Data
x = [1, 2, 3, 4]
y = [2, 4, 1, 3]

# Create the plot
plt.plot(x, y)

# Add title and labels
plt.title("Basic Line Plot")
# Out:
# Text(0.5, 1.0, 'Basic Line Plot')

# %%
import pandas as pd

# Create a sample DataFrame
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David'],
    'Age': [24, 27, 22, 32],
    'City': ['New York', 'Los Angeles', 'Chicago', 'Houston']
}
df = pd.DataFrame(data)

# Save the DataFrame to an Excel file
excel_file_name = 'sample_data.xlsx'
df.to_excel(excel_file_name, index=False)

print(f"DataFrame successfully saved to '{excel_file_name}'")
# Out:
# DataFrame successfully saved to 'sample_data.xlsx'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls
# Out:
# drive  sample_data  sample_data.xlsx

# %%
drive.flush_and_unmount()

# %%
a = 56

# %%
b = 45

# %%
a_coding = 55

# %%
b_coding = 23

# %%
from google.colab import userdata
secret = userdata.get('OPEN_API')

# %%
secret
# Out:
# 'aksnx123nalxnlxla123456'
