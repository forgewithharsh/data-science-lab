# %%
import numpy as np
arr = np.array([23, 4, 3, 23])

# %%
arr.dtype
# Out:
# dtype('int64')

# %%
arr.astype("float64")
# Out:
# array([23.,  4.,  3., 23.])

# %%
arr2 = np.array([23, 4, 3, 23], dtype="float32")

# %%
arr2
# Out:
# array([23.,  4.,  3., 23.], dtype=float32)
