# %%
f = open("text.txt", "r")

# %%
f.read()
# Out:
# 'Harry\nis\ngood \nboy'

# %%
s = "This is a nice way to learn Data Science"

# %%
f.close()

# %%
f = open("harry.txt","w")

# %%
f.write(s)
# Out:
# 40

# %%
f.close()
